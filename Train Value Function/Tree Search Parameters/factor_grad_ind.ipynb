# %%
import numpy as np
import time
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, random_split
import torch.optim as optim
import matplotlib.pyplot as plt
import sys, os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(project_root)

from Resources.Model import Model_v25
from Resources.Game import *
from Resources.TS_ModelGuided import *
from Resources.TS_ModelGuided_MCRollout import *
from Resources.TS_ModelGuided_SensAnalysis import *

from test_games import test_games

# %% [markdown]
# ##### Setup Model

# %%
model = Model_v25()
model.eval()
model.load_state_dict(torch.load('../Monte Carlo/Model Saves MC v25/model_2000_batches'))
# Out:
# <All keys matched successfully>

# %%
n_games = 1
tmax = 1

# [wins, value sum, value ind, grad sum, grad ind, exploration]
factors = [1.0, 0.0, 1.0, 1.0, 0.0, 0.0, 1e-3]
factors = np.array(factors)

test_factors = [-0.5, -0.15, -0.05, 0, 0.05, 0.15, 0.5]
test_results = [[0, 0, 0] for _ in test_factors]

number_games = 0

# %%
while True:

    for t, test_factor in enumerate(test_factors):
        if t in [0]:
            continue

        factors_test = factors.copy()
        factors_test[5] = test_factor

        wins_1, draws, wins_2 = test_games(n_games, model, tmax, 
                                        factors, factors_test)
        
        number_games += 1

        if wins_1 == 1:
            test_results[t][0] += 1

        if draws == 1:
            test_results[t][1] += 1

        if wins_2 == 1:
            test_results[t][2] += 1

    print(number_games)
# Out:
# 344
# 350
# 356
# 362
# 368
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/Philip/Desktop/GitHub/ChessEngine/Train Value Function/Tree Search Parameters/factor_grad_ind.ipynb Cell 5 line 1
#       <a href='vscode-notebook-cell:/Users/Philip/Desktop/GitHub/ChessEngine/Train%20Value%20Function/Tree%20Search%20Parameters/factor_grad_ind.ipynb#X25sZmlsZQ%3D%3D?line=6'>7</a> factors_test = factors.copy()
#       <a href='vscode-notebook-cell:/Users/Philip/Desktop/GitHub/ChessEngine/Train%20Value%20Function/Tree%20Search%20Parameters/factor_grad_ind.ipynb#X25sZmlsZQ%3D%3D?line=7'>8</a> factors_test[5] = test_factor
# ---> <a href='vscode-notebook-cell:/Users/Philip/Desktop/GitHub/ChessEngine/Train%20Value%20Function/Tree%20Search%20Parameters/factor_grad_ind.ipynb#X25sZmlsZQ%3D%3D?line=9'>10</a> wins_1, draws, wins_2 = test_games(n_games, model, tmax,
#      <a href='vscode-notebook-cell:/Users/Philip/Desktop/GitHub/ChessEngine/Train%20Value%20Function/Tree%20Search%20Parameters/factor_grad_ind.ipynb#X25sZmlsZQ%3D%3D?line=10'>11</a>                                 factors, factors_test)
#      <a href='vscode-notebook-cell:/Users/Philip/Desktop/GitHub/ChessEngine/Train%20Value%20Function/Tree%20Search%20Parameters/factor_grad_ind.ipynb#X25sZmlsZQ%3D%3D?line=12'>13</a> number_games += 1
#      <a href='vscode-notebook-cell:/Users/Philip/Desktop/GitHub/ChessEngine/Train%20Value%20Function/Tree%20Search%20Parameters/factor_grad_ind.ipynb#X25sZmlsZQ%3D%3D?line=14'>15</a> if wins_1 == 1:
#
# File ~/Desktop/GitHub/ChessEngine/Train Value Function/Tree Search Parameters/test_games.py:50, in test_games(n_games, model, tmax, factors_1, factors_2)
#      47 else:
#      48     factors = factors_2
# ---> 50 chosen_move, root = SensAnalysis_TS(game, model, factors=factors, root=None, tmax=tmax, prints=False)
#      52 game.PlayMove(chosen_move)
#      53 game.FlipBoard()
#
# File ~/Desktop/GitHub/ChessEngine/Resources/TS_ModelGuided_SensAnalysis.py:92, in SensAnalysis_TS(game, model, root, tmax, batches, prints, factors, factor_wins, factor_mat, factor_value_sum, factor_value_indi, factor_grad_sum, factor_grad_indi, factor_explore, sensitivity_extraction, use_gradients)
#      90 # Selection
#      91 while not node.is_leaf() and node.is_fully_expanded():
# ---> 92     node = node.select_child()
#      94 # Expansion
#      95 if not node.is_fully_expanded():
#
# File ~/Desktop/GitHub/ChessEngine/Resources/TS_ModelGuided_SensAnalysis.py:205, in SensAnalysis_Node.select_child(self)
#     199 self.values_win = [child.wins / max(child.visits, 1)
#     200                 for child in self.children]
#     202 self.values_mat = [np.tanh(child.matdiff_rollmed.get_median() + self.matdiff)
#     203                 for child in self.children]
# --> 205 self.values_value_sum = [np.tanh(child.value_rollmed.get_median() - mean_next_value)
#     206                         if (child.value_rollmed.get_median() is not None and mean_next_value is not None) else 0
#     207                 for child in self.children]
#     209 self.values_value_indi = [child.value - mean_next_value
#     210                           if (child.value is not None and mean_next_value is not None) else 0
#     211                 for child in self.children]
#     213 self.values_grad_sum = [np.tanh(child.grad_rollmed.get_median())
#     214                          if (child.grad_rollmed.get_median() is not None) else 0
#     215                 for child in self.children]
#
# File ~/Desktop/GitHub/ChessEngine/Resources/TS_ModelGuided_SensAnalysis.py:205, in <listcomp>(.0)
#     199 self.values_win = [child.wins / max(child.visits, 1)
#     200                 for child in self.children]
#     202 self.values_mat = [np.tanh(child.matdiff_rollmed.get_median() + self.matdiff)
#     203                 for child in self.children]
# --> 205 self.values_value_sum = [np.tanh(child.value_rollmed.get_median() - mean_next_value)
#     206                         if (child.value_rollmed.get_median() is not None and mean_next_value is not None) else 0
#     207                 for child in self.children]
#     209 self.values_value_indi = [child.value - mean_next_value
#     210                           if (child.value is not None and mean_next_value is not None) else 0
#     211                 for child in self.children]
#     213 self.values_grad_sum = [np.tanh(child.grad_rollmed.get_median())
#     214                          if (child.grad_rollmed.get_median() is not None) else 0
#     215                 for child in self.children]
#
# KeyboardInterrupt:

# %%
for i in test_results:
    print(sum(i), i)
# Out:
# 28 [20, 5, 3]
# 59 [21, 14, 24]
# 59 [25, 8, 26]
# 54 [22, 9, 23]
# 56 [25, 12, 19]
# 55 [21, 18, 16]
# 27 [14, 8, 5]

# %%
plt.plot([i[0]/sum(i) for i in test_results], label='wins 1')
plt.plot([i[1]/sum(i) for i in test_results], label='draws')
plt.plot([i[2]/sum(i) for i in test_results], label='wins_2')
plt.legend()
plt.show()
