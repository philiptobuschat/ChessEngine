# %%
import numpy as np
import time
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader, random_split
import torch.optim as optim
import matplotlib.pyplot as plt
import sys, os

project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.append(project_root)

from Resources.Model import Model_v25
from Resources.Game import *
from Resources.TS_ModelGuided import *
from Resources.TS_ModelGuided_MCRollout import *
from Resources.TS_ModelGuided_SensAnalysis import *

from test_games import test_games

# %% [markdown]
# ##### Setup Model

# %%
model = Model_v25()
model.eval()
model.load_state_dict(torch.load('../Monte Carlo/Model Saves MC v25/model_2000_batches'))
# Out:
# <All keys matched successfully>

# %%
n_games = 1
tmax = 1

# [wins, value sum, value ind, grad sum, grad ind, exploration]
factors = [1.0, 0.0, 1.0, 1.0, 0.0, 0.0, 1e-3]
factors = np.array(factors)

test_factors = [-0.5, -0.15, -0.05, 0, 0.05, 0.15, 0.5]
test_results = [[0, 0, 0] for _ in test_factors]

number_games = 0

# %%
while True:

    for t, test_factor in enumerate(test_factors):
        if t in [0, 1, 6]:
            continue
        factors_test = factors.copy()
        factors_test[5] = test_factor

        wins_1, draws, wins_2 = test_games(n_games, model, tmax, 
                                        factors, factors_test, sensitivity_extraction=sensitivity_extraction_4)
        
        number_games += 1

        if wins_1 == 1:
            test_results[t][0] += 1

        if draws == 1:
            test_results[t][1] += 1

        if wins_2 == 1:
            test_results[t][2] += 1

    print(number_games)
# Out:
# 246
# 250
# 254
# 258
# 262
# 266
# 270
# 274
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/Philip/Desktop/GitHub/ChessEngine/Train Value Function/Tree Search Parameters/factor_grad_ind_Method4.ipynb Cell 5 line 9
#       <a href='vscode-notebook-cell:/Users/Philip/Desktop/GitHub/ChessEngine/Train%20Value%20Function/Tree%20Search%20Parameters/factor_grad_ind_Method4.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> factors_test = factors.copy()
#       <a href='vscode-notebook-cell:/Users/Philip/Desktop/GitHub/ChessEngine/Train%20Value%20Function/Tree%20Search%20Parameters/factor_grad_ind_Method4.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a> factors_test[5] = test_factor
# ----> <a href='vscode-notebook-cell:/Users/Philip/Desktop/GitHub/ChessEngine/Train%20Value%20Function/Tree%20Search%20Parameters/factor_grad_ind_Method4.ipynb#X12sZmlsZQ%3D%3D?line=8'>9</a> wins_1, draws, wins_2 = test_games(n_games, model, tmax,
#      <a href='vscode-notebook-cell:/Users/Philip/Desktop/GitHub/ChessEngine/Train%20Value%20Function/Tree%20Search%20Parameters/factor_grad_ind_Method4.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a>                                 factors, factors_test, sensitivity_extraction=sensitivity_extraction_4)
#      <a href='vscode-notebook-cell:/Users/Philip/Desktop/GitHub/ChessEngine/Train%20Value%20Function/Tree%20Search%20Parameters/factor_grad_ind_Method4.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> number_games += 1
#      <a href='vscode-notebook-cell:/Users/Philip/Desktop/GitHub/ChessEngine/Train%20Value%20Function/Tree%20Search%20Parameters/factor_grad_ind_Method4.ipynb#X12sZmlsZQ%3D%3D?line=13'>14</a> if wins_1 == 1:
#
# File ~/Desktop/GitHub/ChessEngine/Train Value Function/Tree Search Parameters/test_games.py:50, in test_games(n_games, model, tmax, factors_1, factors_2, sensitivity_extraction)
#      47 else:
#      48     factors = factors_2
# ---> 50 chosen_move, root = SensAnalysis_TS(game, model, factors=factors,
#      51                                     root=None, tmax=tmax, prints=False,
#      52                                     sensitivity_extraction=sensitivity_extraction)
#      54 game.PlayMove(chosen_move)
#      55 game.FlipBoard()
#
# File ~/Desktop/GitHub/ChessEngine/Resources/TS_ModelGuided_SensAnalysis.py:92, in SensAnalysis_TS(game, model, root, tmax, batches, prints, factors, factor_wins, factor_mat, factor_value_sum, factor_value_indi, factor_grad_sum, factor_grad_indi, factor_explore, sensitivity_extraction, use_gradients)
#      90 # Selection
#      91 while not node.is_leaf() and node.is_fully_expanded():
# ---> 92     node = node.select_child()
#      94 # Expansion
#      95 if not node.is_fully_expanded():
#
# File ~/Desktop/GitHub/ChessEngine/Resources/TS_ModelGuided_SensAnalysis.py:240, in SensAnalysis_Node.select_child(self)
#     228 self.children_values = [
#     229       self.factors[0]   * self.values_win[c]
#     230     + self.factors[1]   * self.values_mat[c]
#    (...)
#     236     for c, child in enumerate(self.children)
#     237 ]
#     239 # select child with highest ucb value or random one of the best ones
# --> 240 max_value = max(self.children_values)
#     241 max_indices = [i for i, value in enumerate(self.children_values) if value == max_value]
#     242 selected_index = random.choice(max_indices)
#
# KeyboardInterrupt:

# %%
for i in test_results:
    print(sum(i), i)
# Out:
# 33 [31, 2, 0]
# 33 [21, 7, 5]
# 33 [13, 9, 11]
# 33 [13, 6, 14]
# 33 [12, 5, 16]
# 33 [16, 5, 12]
# 32 [26, 3, 3]

# %%
plt.plot([i[0]/sum(i) for i in test_results], label='wins 1')
plt.plot([i[1]/sum(i) for i in test_results], label='draws')
plt.plot([i[2]/sum(i) for i in test_results], label='wins_2')
plt.xlabel([-0.5, -0.15, -0.05, 0.0, 0.05, 0.15, 0.5])
plt.legend()
plt.show()
